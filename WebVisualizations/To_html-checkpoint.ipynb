# %%
# Dependencies
import pandas as pd

# %%
# Store filepath in a variable
weather_data = "Resources/Weather_Data.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
weather_data__df = pd.read_csv(weather_data, encoding="ISO-8859-1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-5749692eea27> in <module>
#       1 # Read our Data file with the pandas library
#       2 # Not every CSV requires an encoding, but be aware this can come up
# ----> 3 file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")
#
# ...

# %%
# Show just the header
weather_data_df.head()
# Out:
#    id first_name  last_name                    email  gender
# 0   1      David     Jordan         djordan0@home.pl    Male
# 1   2    Stephen      Riley  sriley1@hugedomains.com    Male
# 2   3     Evelyn      Grant  egrant2@livejournal.com  Female
# 3   4        Joe    Mendoza         jmendoza3@un.org    Male
# 4   5   Benjamin  Rodriguez   brodriguez4@elpais.com    Male

# %%
# Reorganizing the columns using double brackets
organized_df = weather_data[["City","Country","Temperature","Humidity", "Clouds", "Wind Speed", "Latitude", "Longitude"]]
organized_df.head()

# %%
# convert file to html
organized_df.to_html('Weather_Data_PD.html')
